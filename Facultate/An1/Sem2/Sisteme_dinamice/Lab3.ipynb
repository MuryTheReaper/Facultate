# %%
#1a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+4*y
e2=diff(y,t)==x+y
sys=[e1,e2]
desolve_system(sys,[x,y])
# Out:
# [x(t) == 1/2*(x(0) + 2*y(0))*e^(3*t) + 1/2*(x(0) - 2*y(0))*e^(-t),
#  y(t) == 1/4*(x(0) + 2*y(0))*e^(3*t) - 1/4*(x(0) - 2*y(0))*e^(-t)]

# %%
#b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==2*x-y
e2=diff(y,t)==x+2*y
sys=[e1,e2]
desolve_system(sys,[x,y])
# Out:
# [x(t) == (cos(t)*x(0) - sin(t)*y(0))*e^(2*t),
#  y(t) == (sin(t)*x(0) + cos(t)*y(0))*e^(2*t)]

# %%
#c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
e1=diff(x,t)==x-y+z
e2=diff(y,t)==x+y-z
e3=diff(z,t)==-y+2*z
sys=[e1,e2,e3]
desolve_system(sys,[x,y,z])
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (2*x(0) + y(0) - 2*z(0))*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + e^t*y(0),
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) + y(0) - 2*z(0))*e^(2*t) + (x(0) + y(0) - z(0))*e^t]

# %%
#d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==5*x+3*y+1
e2=diff(y,t)==-6*x-4*y+e^(-t)
sys=[e1,e2]
desolve_system(sys,[x,y])
# Out:
# [x(t) == 1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) - t*e^(-t) - 1/3*(3*x(0) + 3*y(0) - 2)*e^(-t) - 2,
#  y(t) == -1/3*(6*x(0) + 3*y(0) + 4)*e^(2*t) + 2*t*e^(-t) + 1/3*(6*x(0) + 6*y(0) - 5)*e^(-t) + 3]

# %%
#e
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+3*y+cos(t)
e2=diff(y,t)==x-y+2*t
sys=[e1,e2]
desolve_system(sys,[x,y])
# Out:
# [x(t) == 3/40*(10*x(0) + 10*y(0) + 9)*e^(2*t) + 1/40*(10*x(0) - 30*y(0) - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*x(0) + 10*y(0) + 9)*e^(2*t) - 1/40*(10*x(0) - 30*y(0) - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
#f
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
e1=diff(x,t)==x-2*y-2*z+e^(-t)
e2=diff(y,t)==-2*x+y+2*z
e3=diff(z,t)==2*x-y-3*z+e^(-t)
sys=[e1,e2,e3]
desolve_system(sys,[x,y,z])
# Out:
# [x(t) == 1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t) - cosh(sqrt(3)*t)*y(0),
#  y(t) == -1/3*sqrt(3)*(2*x(0) - y(0) - 2*z(0))*sinh(sqrt(3)*t) + cosh(sqrt(3)*t)*y(0),
#  z(t) == sqrt(3)*(x(0) - z(0))*sinh(sqrt(3)*t) - (x(0) + y(0) - z(0))*cosh(sqrt(3)*t) + t*e^(-t) + (x(0) + y(0))*e^(-t)]

# %%
#2a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+4*y
e2=diff(y,t)==x+y
sys=[e1,e2]
vars=[x,y]
cond=[0,1,2]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
gx=plot(sol_x(t),t,-4,4,color='red')
gy=plot(sol_y(t),t,-4,4,color='blue')
show(gx+gy)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x-y+t-1
e2=diff(y,t)==-2*x+4*y+cos(t)
sys=[e1,e2]
vars=[x,y]
cond=[0,0,1]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
gx=plot(sol_x(t),t,-4,4,color='red')
gy=plot(sol_y(t),t,-4,4,color='blue')
show(gx+gy)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+2*y+e^(-t)
e2=diff(y,t)==-2*x+y+1
sys=[e1,e2]
vars=[x,y]
cond=[0,0,1]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
gx=plot(sol_x(t),t,-4,4,color='red')
gy=plot(sol_y(t),t,-4,4,color='blue')
show(gx+gy)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#2d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
e1=diff(x,t)==-x+3*y+3*z+27*t^2
e2=diff(y,t)==2*x-2*y-5*z+3*t
e3=diff(z,t)==-2*x+3*y+6*z+3
sys=[e1,e2,e3]
vars=[x,y,z]
cond=[0,50,-30,26]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
sol_z(t)=sol[2].rhs()
gx=plot(sol_x(t),t,-4,4,color='red')
gy=plot(sol_y(t),t,-4,4,color='blue')
gz=plot(sol_z(t),t,-4,4,color='green')
show(gx+gy+gz)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#3a1
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,3,0]
sol=desolve_system(sys,vars,cond)
show(sol)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]

# %%
#3a2
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,3]
sol=desolve_system(sys,vars,cond)
show(sol)
# Out:
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]

# %%
#3a3
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
show(sol)
# Out:
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]

# %%
#3a4
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,-3]
sol=desolve_system(sys,vars,cond)
show(sol)
# Out:
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]

# %%
#3b1
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,3,0]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
l1=limit(sol_x(t),t=oo)
l2=limit(sol_y(t),t=oo)
show(l1,l2)
# Out:
# -Infinity -Infinity

# %%
#3b2
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,3]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
l1=limit(sol_x(t),t=oo)
l2=limit(sol_y(t),t=oo)
show(l1,l2)
# Out:
# +Infinity +Infinity

# %%
#3b3
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
l1=limit(sol_x(t),t=oo)
l2=limit(sol_y(t),t=oo)
show(l1,l2)
# Out:
# +Infinity +Infinity

# %%
#3b4
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,-3]
sol=desolve_system(sys,vars,cond)
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
l1=limit(sol_x(t),t=oo)
l2=limit(sol_y(t),t=oo)
show(l1,l2)
# Out:
# -Infinity -Infinity

# %%
#3c1
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=x+y
f2(x,y)=-2*x+4*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-10,10),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3c2
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,3]
sol=desolve_system(sys,vars,cond)
f1(x,y)=x+y
f2(x,y)=-2*x+4*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-10,10),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3c3
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=x+y
f2(x,y)=-2*x+4*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-10,10),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3c1
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x+y
e2=diff(y,t)==-2*x+4*y
sys=[e1,e2]
vars=[x,y]
cond=[0,0,-3]
sol=desolve_system(sys,vars,cond)
f1(x,y)=x+y
f2(x,y)=-2*x+4*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-10,10),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#4a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==y
e2=diff(y,t)==-x-2*y
sys=[e1,e2]
sol=desolve_system(sys,[x,y])
show(sol)
# Out:
# [x(t) == t*e^(-t)*x(0) + 3*t*e^(-t) + e^(-t)*x(0),
#  y(t) == -t*e^(-t)*x(0) - 3*t*e^(-t) + 3*e^(-t)]

# %%
#4b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==y
e2=diff(y,t)==-x-2*y
sys=[e1,e2]
sol=desolve_system(sys,[x,y])
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
l1=limit(sol_x(t),t=oo)
l2=limit(sol_y(t),t=oo)
show(l1,l2)
# Out:
# 0 0

# %%
#4c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
f1(x,y)=y
f2(x,y)=-x-2*y
g=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
show(g)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5a
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
f1(x,y)=2*x+y
f2(x,y)=x+2*y
g=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
show(g)
#nu are limita 0
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5b
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==-x-y
e2=diff(y,t)==x-y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=-x-y
f2(x,y)=x-y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-5,5),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
#are limita 0
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#5c
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==y
e2=diff(y,t)==-x
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=y
f2(x,y)=-x
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-5,5),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
#nu are limita 0
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#5d
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==-2*x
e2=diff(y,t)==-4*x-2*y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=-2*x
f2(x,y)=-4*x-2*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-5,5),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
#are limita 0
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#5e
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==x-4*y
e2=diff(y,t)==5*x-3*y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=x-4*y
f2(x,y)=5*x-3*y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-5,5),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
#are limita 0
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#5f
reset()
t=var('t')
x=function('x')(t)
y=function('y')(t)
e1=diff(x,t)==3*x-y
e2=diff(y,t)==y
sys=[e1,e2]
vars=[x,y]
cond=[0,-3,0]
sol=desolve_system(sys,vars,cond)
f1(x,y)=3*x-y
f2(x,y)=y
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot_vector_field([f1(x,y),f2(x,y)],[x,-5,5],[y,-5,5], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x(t),sol_y(t)),(t,-5,5),color='blue')
g=g1+g2
g.show(xmin=-5,xmax=5,ymin=-5,ymax=5)
#nu are limita 0
# Out:
# Graphics object consisting of 2 graphics primitives
